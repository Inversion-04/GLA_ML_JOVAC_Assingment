# %%
import pandas as pd
import numpy as np

# Task 1: Working with Series

# 1. Create a Pandas Series from the following list:

data = [25, 30, 35, 40, 45]
series = pd.Series(data)
print("Pandas Series:\n", series)

# 2. Assign custom indices ['A', 'B', 'C', 'D', 'E'] to the Series

updated_series = pd.Series(data, index=['A', 'B', 'C', 'D', 'E'])
print("\nUpdated Series with custom indices:\n", updated_series)

# Display the first three elements of the Series

print("\nFirst 3 elements:\n", updated_series[:3])

# Calculate mean, median, and standard deviation

mean_val = updated_series.mean()
median_val = updated_series.median()
std_dev = updated_series.std()


print("Mean:", mean_val)
print("Median:", median_val)
print("Standard Deviation:", std_dev)
# Out:
# Pandas Series:
#  0    25
# 1    30
# 2    35
# 3    40
# 4    45
# dtype: int64
#
# Updated Series with custom indices:
#  A    25
# B    30
# C    35
# D    40
# E    45
# dtype: int64
#
# First 3 elements:
#  A    25
# B    30
# C    35
# dtype: int64
# Mean: 35.0
# Median: 35.0
# Standard Deviation: 7.905694150420948

# %%
import pandas as pd

#Task 2: Creating and Inspecting DataFrames

# 1. Create the DataFrame

data = {
    'Name': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
    'Age': [20, 22, 19, 21, 20],
    'Gender': ['Female', 'Male', 'Female', 'Male', 'Female'],
    'Marks': [85, 78, 92, 74, 88]
}

df = pd.DataFrame(data)

# 2. Display the first two rows

print("\nFirst two rows:\n\n", df.head(2))

# Display column names, data types

print("\nColumn Names:", df.columns.tolist())
print("\nData Types:\n\n", df.dtypes)

# Display summary statistics

print("\nSummary Statistics:\n\n", df.describe())

# Add 'Passed' column (True if Marks >= 80, else False)

df['Passed'] = df['Marks'] >= 80
print("\nDataFrame with 'Passed' column:\n\n", df)
# Out:
# First two rows:
#
#      Name  Age  Gender  Marks
# 0  Alice   20  Female     85
# 1    Bob   22    Male     78
#
# Column Names: ['Name', 'Age', 'Gender', 'Marks']
#
# Data Types:
#
#  Name      object
# Age        int64
# Gender    object
# Marks      int64
# dtype: object
#
# Summary Statistics:
#
#               Age      Marks
# count   5.000000   5.000000
# mean   20.400000  83.400000
# std     1.140175   7.334848
# min    19.000000  74.000000
# 25%    20.000000  78.000000
# 50%    20.000000  85.000000
# 75%    21.000000  88.000000
# max    22.000000  92.000000
#
# DataFrame with 'Passed' column:
#
#      Name  Age  Gender  Marks  Passed
# 0  Alice   20  Female     85    True
# 1    Bob   22    Male     78   False
# 2  Carol   19  Female     92    True
# 3  David   21    Male     74   False
# 4    Eve   20  Female     88    True

# %%
import pandas as pd

# Task 3: Data Selection and Filtering

# 1.Using the DataFrame from Task 2, write a Python program to:

data = {
    'Name': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
    'Age': [20, 22, 19, 21, 20],
    'Gender': ['Female', 'Male', 'Female', 'Male', 'Female'],
    'Marks': [85, 78, 92, 74, 88]
}

df = pd.DataFrame(data)

#Select and display the Name and Marks columns.

print("Name and Marks columns:\n")
print(df[['Name', 'Marks']])

#Filter and display records where Marks > 80.
print("\nStudents with Marks > 80:\n")
print(df[df['Marks'] > 80])

#Display the record of the student with the highest marks.

print("\nStudent with the Highest Marks:\n")
print(df[df['Marks'] == df['Marks'].max()])
# Out:
# Name and Marks columns:
#
#     Name  Marks
# 0  Alice     85
# 1    Bob     78
# 2  Carol     92
# 3  David     74
# 4    Eve     88
#
# Students with Marks > 80:
#
#     Name  Age  Gender  Marks
# 0  Alice   20  Female     85
# 2  Carol   19  Female     92
# 4    Eve   20  Female     88
#
# Student with the Highest Marks:
#
#     Name  Age  Gender  Marks
# 2  Carol   19  Female     92

# %%
import pandas as pd

# Task 4: Handling Missing Data

# Re-create the original DataFrame from Task 2

data = {
    'Name': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
    'Age': [20, 22, 19, 21, 20],
    'Gender': ['Female', 'Male', 'Female', 'Male', 'Female'],
    'Marks': [85, 78, 92, 74, 88]
}

df = pd.DataFrame(data)

# 1. Introduce missing values

df.loc[1, 'Marks'] = None   
df.loc[4, 'Age'] = None     

print("DataFrame with Missing Values:\n")
print(df)

# 2. Identify missing values

print("\nMissing Values (True indicates missing):\n")
print(df.isnull())

# 3. Fill missing values in 'Marks' column with mean of the column

mean_marks = df['Marks'].mean()
df['Marks'] = df['Marks'].fillna(mean_marks)


print("\nDataFrame after filling missing Marks with mean:\n")
print(df)

# 4. Drop rows where 'Age' is missing

new_df = df.dropna(subset=['Age'])

print("\nFinal DataFrame after dropping rows with missing Age:\n")
print(new_df)
# Out:
# DataFrame with Missing Values:
#
#     Name   Age  Gender  Marks
# 0  Alice  20.0  Female   85.0
# 1    Bob  22.0    Male    NaN
# 2  Carol  19.0  Female   92.0
# 3  David  21.0    Male   74.0
# 4    Eve   NaN  Female   88.0
#
# Missing Values (True indicates missing):
#
#     Name    Age  Gender  Marks
# 0  False  False   False  False
# 1  False  False   False   True
# 2  False  False   False  False
# 3  False  False   False  False
# 4  False   True   False  False
#
# DataFrame after filling missing Marks with mean:
#
#     Name   Age  Gender  Marks
# 0  Alice  20.0  Female  85.00
# 1    Bob  22.0    Male  84.75
# 2  Carol  19.0  Female  92.00
# 3  David  21.0    Male  74.00
# 4    Eve   NaN  Female  88.00
#
# Final DataFrame after dropping rows with missing Age:
#
#     Name   Age  Gender  Marks
# 0  Alice  20.0  Female  85.00
# 1    Bob  22.0    Male  84.75
# 2  Carol  19.0  Female  92.00
# 3  David  21.0    Male  74.00

# %%
import pandas as pd

# Task 5: Grouping and Aggregation

# Re-create the original DataFrame (from Task 2)

data = {
    'Name': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
    'Age': [20, 22, 19, 21, 20],
    'Gender': ['Female', 'Male', 'Female', 'Male', 'Female'],
    'Marks': [85, 78, 92, 74, 88]
}

df = pd.DataFrame(data)

# 1. Group by Gender and calculate mean Age and Marks

grouped_mean = df.groupby('Gender')[['Age', 'Marks']].mean()
print("Mean Age and Marks by Gender:\n")
print(grouped_mean)

# 2. Count number of students in each gender group

gender_counts = df['Gender'].value_counts()
print("\nNumber of Students by Gender:\n")
print(gender_counts)
# Out:
# Mean Age and Marks by Gender:
#
#               Age      Marks
# Gender
# Female  19.666667  88.333333
# Male    21.500000  76.000000
#
# Number of Students by Gender:
#
# Gender
# Female    3
# Male      2
# Name: count, dtype: int64

# %%
# Task 6: Reading and Writing Data

import pandas as pd

# Re-create and modify the original DataFrame (like in Task 4)

data = {
    'Name': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
    'Age': [20, 22, 19, 21, None],         # Eve's Age is missing
    'Gender': ['Female', 'Male', 'Female', 'Male', 'Female'],
    'Marks': [85, None, 92, 74, 88]        # Bob's Marks are missing
}

df = pd.DataFrame(data)

# Fill missing 'Marks' with mean

mean_marks = df['Marks'].mean()
df['Marks'] = df['Marks'].fillna(mean_marks)

# Drop rows with missing 'Age'

df1 = df.dropna(subset=['Age'])

#  1. Save to CSV
df1.to_csv('students_data.csv', index=False)
print("Data saved to 'students_data.csv'")

#  2. Read from CSV into a new DataFrame

new_df = pd.read_csv('students_data.csv')

#  3. Display first 5 rows

print("\nFirst 5 rows of the loaded DataFrame:\n")
print(new_df.head())
# Out:
# Data saved to 'students_data.csv'
#
# First 5 rows of the loaded DataFrame:
#
#     Name   Age  Gender  Marks
# 0  Alice  20.0  Female  85.00
# 1    Bob  22.0    Male  84.75
# 2  Carol  19.0  Female  92.00
# 3  David  21.0    Male  74.00

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/ShubhamSinghal12/GLA_pythonML2025/refs/heads/main/Data%20Visualization/Titanic.csv"
df = pd.read_csv(url)

# Summary Statistics

print("\nSummary Statistics:\n\n", df.describe(include='all'))

# Missing Value Check

print("\nMissing Values Count:\n\n", df.isnull().sum())



# Data Visualization: Plots and Curves


# Age Distribution

plt.figure(figsize=(7,4))
sns.histplot(df['Age'], bins=30, kde=True, color='skyblue')
plt.title("Age Distribution with Curve (KDE)")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()


# Fare Distribution

plt.figure(figsize=(7,4))
sns.histplot(df['Fare'], bins=30, kde=True, color='lightgreen')
plt.title("Fare Distribution with Curve (KDE)")
plt.xlabel("Fare")
plt.ylabel("Count")
plt.show()


# Gender vs Survival

plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Sex', hue='Survived', palette='Set2')
plt.title("Gender vs Survival")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# Pclass vs Survival

plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Pclass', hue='Survived', palette='Set1')
plt.title("Class vs Survival")
plt.xlabel("Passenger Class")
plt.ylabel("Count")
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()


# Embarked vs Survival

plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Embarked', hue='Survived', palette='Set3')
plt.title("Embarked Port vs Survival")
plt.xlabel("Port")
plt.ylabel("Count")
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()


# Heatmap of Correlation

plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()


# ---------------------------
# Findings
# --------------------------


# Missing Values

#  Age has 177 missing values — important for future modeling or imputation.
#  Cabin is mostly missing — may not be useful without feature engineering.
#  Embarked has only 2 missing entries — can be safely filled with the mode.



# 1. Age Distribution

#  Most passengers were between 20–30 years old.
#  Few were very old or very young.
#  The shape is right-skewed.

# 2. Fare Distribution

#  Many passengers paid low fares.
#  A few paid very high fares.
#  The fare is highly skewed.

# 3. Gender vs Survival

#  More females survived than males.
#  Males had higher death rates.

# 4. Pclass vs Survival

#  1st class passengers survived more.
#  3rd class had the least survival.

# 5. Embarked vs Survival

#  Most passengers got on at port 'S' (Southampton).
#  At port 'C' (Cherbourg), the number of survivors was higher than non-survivors,
#   which is not the case for other ports.
#  Port 'Q' (Queenstown) had the lowest number of passengers and survivors.

# 6. Correlation Heatmap (Key Points)

#  Fare is positively correlated with survival.
#  Pclass is negatively correlated with survival.
# Out:
# Summary Statistics:
#
#          PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...
